# %% [markdown]
# <a href="https://colab.research.google.com/github/oumaruhsow-dev/Machine-Learning-with-Python-Bootcamp/blob/main/Python_refresher.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Variables

# %%
# Creat a labeled storage basket and put a number inside
tomato_price = 150
pepper_price = 80

# pull the value out of the baskets
print(tomato_price)
print(pepper_price)
# Out:
# 150
# 80

# %% [markdown]
# VARIABLES (ML Anchor)

# %%
# --- THE CLUES (Features grouped as X) ---
rainfall_mm = 45.2    # Clue 1
bags_available = 100  # Clue 2

# --- THE GOAL (Target labeled as y) ---
predicted_price = 3200 # what our AI calculates

print("Inputs (x):", rainfall_mm, "mm rain,", bags_available, "bags.")
print("output (x):", predicted_price, "LRD.")
# Out:
# Inputs (x): 45.2 mm rain, 100 bags.
# output (x): 3200 LRD.

# %% [markdown]
# Understanding print statements.

# %%
Liberia = 1847
print(Liberia) #value will appear
print("Liberia") #text will appear
# Out:
# 1847
# Liberia

# %% [markdown]
# Understanding Variables.

# %%
plum=50
print("Plum previous price was:",plum)
plum=80
print("Plum new price is:",plum)
# Out:
# Plum previous price was: 50
# Plum new price is: 80

# %% [markdown]
# DATA TYPES

# %%
quantity = 50
price = 150.50
item_name = "tomatoes"
stall_is_open =True

print(type(quantity)) #
print(type(price)) #
print(type(item_name)) #
print(type(stall_is_open)) #
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>
